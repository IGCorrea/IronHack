# %%
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
c=0
d=0
e=0

while (e<10):
  Atk_gandalf = input("Please choose one power for Gandalf: ")
  if Atk_gandalf not in ['10', '11', '13', '30', '22', '11', '10', '33','22', '22']:
    print( "it isn't a power for Gandalf")
    Atk_gandalf = input("Please choose one power for Gandalf: ")
  else:
    a = int(Atk_gandalf)

  Atk_saruman = input("Please choose one power for Saruman: ")
  if Atk_saruman not in ['23', '66', '12', '43', '12', '10', '44', '23', '12', '17']:
    print( "it isn't a power for Saruma ")
  else:
    b = int(Atk_saruman)
  if a>b:
    print("Gandalf win this duel")
    c=c+1
    e=e+1
    print("Wins for Gandalf: ",c)
  elif a<b:
    print("Saruman win this duel")
    d=d+1
    e=e+1
    print("Wins for Saruman: ", d)
  else :
    print("This duel is tie")  
    e=e+1

if c>d:
  print("Gandalf wins")
elif c<d:
  print("Saruman wins") 
else:
  print("The battle is tie")
