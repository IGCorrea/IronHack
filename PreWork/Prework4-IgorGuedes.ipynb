# %%
word_freq = {
  'love': 25,
  'conversation': 1,
  'every': 6,
  "we're": 1,
  'plate': 1,
  'sour': 1,
  'jukebox': 1,
  'now': 11,
  'taxi': 1,
  'fast': 1,
  'bag': 1,
  'man': 1,
  'push': 3,
  'baby': 14,
  'going': 1,
  'you': 16,
  "don't": 2,
  'one': 1,
  'mind': 2,
  'backseat': 1,
  'friends': 1,
  'then': 3,
  'know': 2
}
print("Number of keys:", len(word_freq))
print("List of keys:",word_freq.keys())
print("Value for key 'friends':",word_freq['friends'])
print("Value for key 'taxi':",word_freq['taxi'])
print("Value for key 'jukebox':",word_freq['jukebox'])
#check if 'begin 'is a key
if ('begin')in word_freq:
  print("Key begin exist")
else:
  print("key begin doesn't exist")  
#add new keys and values
word_freq['begin']=1
word_freq['start'] = 2
word_freq['over']= 1
word_freq['body']= 17
print(word_freq)

#Convert the dict in a list
print(list(word_freq.keys()))
word = list(word_freq.keys())
print("The first word is:",word[0])
print( 'Number of words in list:',len(word))
print('The last word is:',word[len(word)-1])

#1.2 - A dictionary can't have the same key
#1.3 - A dictionary can have the same value for diferents keys
# Out:
# Number of keys: 23
# List of keys: dict_keys(['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know'])
# Value for key 'friends': 1
# Value for key 'taxi': 1
# Value for key 'jukebox': 1
# key begin doesn't exist
# {'love': 25, 'conversation': 1, 'every': 6, "we're": 1, 'plate': 1, 'sour': 1, 'jukebox': 1, 'now': 11, 'taxi': 1, 'fast': 1, 'bag': 1, 'man': 1, 'push': 3, 'baby': 14, 'going': 1, 'you': 16, "don't": 2, 'one': 1, 'mind': 2, 'backseat': 1, 'friends': 1, 'then': 3, 'know': 2, 'begin': 1, 'start': 2, 'over': 1, 'body': 17}
# ['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know', 'begin', 'start', 'over', 'body']
# The first word is: love
# Number of words in list: 27
# ...
