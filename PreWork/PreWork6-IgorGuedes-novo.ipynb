# %%
def gene(name,born):
  print(name,"is from ",born, "generation")

name1 = "Jonh"
birth_year1 = 1989

if birth_year1 < 1949 :
   birth_year1 = "silent generation"
elif birth_year1<1969:
     birth_year1 = "baby boomer"
elif birth_year1<1981:
    birth_year1= "X generation"
elif birth_year1 <1994:
    birth_year1="millenial"
else:
    birth_year1 = "Z generation"
b=gene(name1,birth_year1)

name2 = "Mari"
birth_year2 = 1995

if birth_year2 < 1949 :
   birth_year2 = "silent generation"
elif birth_year2<1969:
     birth_year2 = "baby boomer"
elif birth_year2<1981:
    birth_year2= "X generation"
elif birth_year2 <1994:
    birth_year2="millenial"
else:
    birth_year2 = "Z generation"
c=gene(name2,birth_year2)

name3 = "Mich"
birth_year3 = 1960

if birth_year3 < 1949 :
    birth_year3 = "silent generation"
elif birth_year3<1969:
      birth_year3 = "baby boomer"
elif birth_year3<1981:
    birth_year3= "X generation"
elif birth_year3 <1994:
    birth_year3 ="millenial"
else:
    birth_year3 = "Z generation"
d = gene(name3,birth_year3)
# Out:
# Jonh is from  millenial generation
# Mari is from  Z generation generation
# Mich is from  baby boomer generation
